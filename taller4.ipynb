# %%
import pandas as pd

# %%
df = pd.read_csv("ecommerce_sales_customer_behavior.csv")
df
# Out:
#         order_id  year  month quarter is_weekend_order       platform  \
# 0     ORD0000001  2022      4      Q2              Yes     AliExpress
# 1     ORD0000002  2023      6      Q2              Yes       Flipkart
# 2     ORD0000003  2022      2      Q1              Yes         Amazon
# 3     ORD0000004  2022      7      Q3               No     AliExpress
# 4     ORD0000005  2024      4      Q2               No          Daraz
# ...          ...   ...    ...     ...              ...            ...
# 9995  ORD0009996  2022      3      Q1               No         Amazon
# 9996  ORD0009997  2021     11      Q4               No         Amazon
# 9997  ORD0009998  2021     10      Q4              Yes           eBay
# 9998  ORD0009999  2023      2      Q1              Yes           eBay
# 9999  ORD0010000  2023      6      Q2               No  Shopify Store
#
#          country customer_segment customer_age_group customer_gender  ...  \
# 0        Germany     New Customer              35-44            Male  ...
# 1      Australia   Loyal Customer              35-44            Male  ...
# 2         Turkey     VIP Customer              45-54            Male  ...
# 3            USA     New Customer              35-44            Male  ...
# 4      Australia   Loyal Customer              35-44          Female  ...
# ...          ...              ...                ...             ...  ...
# 9995   Australia     VIP Customer              45-54            Male  ...
# 9996       India     VIP Customer              45-54          Female  ...
# 9997    Pakistan   Loyal Customer                65+            Male  ...
# 9998  Bangladesh     New Customer              35-44          Female  ...
# 9999       India     VIP Customer              18-24            Male  ...
#
#      return_reason customer_satisfaction session_duration_minutes  \
# 0              NaN          Dissatisfied                     78.7
# 1              NaN               Neutral                     18.2
# 2              NaN     Very Dissatisfied                      5.1
# 3              NaN             Satisfied                     22.0
# 4              NaN             Satisfied                      4.5
# ...            ...                   ...                      ...
# 9995           NaN        Very Satisfied                     14.1
# 9996           NaN             Satisfied                     44.5
# 9997           NaN             Satisfied                      8.9
# 9998           NaN             Satisfied                     62.4
# 9999           NaN             Satisfied                     14.0
#
#       pages_viewed  cart_abandoned_before  wishlist_used  coupon_used  \
# 0                2                    Yes             No           No
# 1                7                     No            Yes           No
# 2                1                     No             No           No
# 3                6                    Yes             No           No
# 4                8                    Yes             No          Yes
# ...            ...                    ...            ...          ...
# 9995             6                     No             No           No
# 9996             8                     No             No           No
# 9997             8                    Yes             No           No
# 9998             4                     No            Yes          Yes
# 9999             2                     No             No           No
#
#       subscription_member  repeat_purchase_count  loyalty_points
# 0                      No                      0               0
# 1                      No                      9             198
# 2                     Yes                     30            1020
# 3                     Yes                      0               0
# 4                      No                     13             598
# ...                   ...                    ...             ...
# 9995                  Yes                     47            2021
# 9996                   No                     37             814
# 9997                   No                      5              50
# 9998                   No                      0               0
# 9999                   No                     32             928
#
# [10000 rows x 38 columns]

# %% [markdown]
# En el df aparecen variables que representan fechas,informacion que identifica al cliente, como el pais, genero, edad, el tipo de cliente que es,datos sobre el tipo de compra que realizo, cuan recurrente es  y datos ordinales representados en si y no (1 y 0).

# %%
df[df["final_amount_usd"] > 500]
# Out:
#         order_id  year  month quarter is_weekend_order    platform    country  \
# 2     ORD0000003  2022      2      Q1              Yes      Amazon     Turkey
# 7     ORD0000008  2024     10      Q4              Yes        eBay      India
# 13    ORD0000014  2022      3      Q1              Yes  AliExpress        UAE
# 18    ORD0000019  2022      3      Q1               No        eBay        UAE
# 22    ORD0000023  2023      3      Q1              Yes      Amazon         UK
# ...          ...   ...    ...     ...              ...         ...        ...
# 9986  ORD0009987  2024      7      Q3              Yes        eBay    Germany
# 9990  ORD0009991  2024      2      Q1              Yes        eBay      India
# 9992  ORD0009993  2021      8      Q3              Yes    Flipkart        UAE
# 9993  ORD0009994  2024      1      Q1               No       Daraz      India
# 9995  ORD0009996  2022      3      Q1               No      Amazon  Australia
#
#         customer_segment customer_age_group customer_gender  ...  \
# 2           VIP Customer              45-54            Male  ...
# 7           New Customer              55-64            Male  ...
# 13          VIP Customer              35-44          Female  ...
# 18    Returning Customer              25-34          Female  ...
# 22        Loyal Customer              35-44            Male  ...
# ...                  ...                ...             ...  ...
# 9986      Loyal Customer              35-44            Male  ...
# 9990      Loyal Customer              45-54            Male  ...
# 9992        VIP Customer              55-64          Female  ...
# 9993   Inactive Customer              35-44            Male  ...
# 9995        VIP Customer              45-54            Male  ...
#
#      return_reason customer_satisfaction session_duration_minutes  \
# 2              NaN     Very Dissatisfied                      5.1
# 7              NaN             Satisfied                     12.8
# 13             NaN             Satisfied                     22.4
# 18      Size Issue             Satisfied                    109.3
# 22             NaN             Satisfied                     78.5
# ...            ...                   ...                      ...
# 9986           NaN        Very Satisfied                      8.8
# 9990           NaN               Neutral                     48.1
# 9992           NaN        Very Satisfied                     76.8
# 9993           NaN             Satisfied                     22.1
# 9995           NaN        Very Satisfied                     14.1
#
#       pages_viewed  cart_abandoned_before  wishlist_used  coupon_used  \
# 2                1                     No             No           No
# 7                6                    Yes             No           No
# 13               4                     No             No          Yes
# 18               6                     No            Yes           No
# 22               6                    Yes            Yes           No
# ...            ...                    ...            ...          ...
# 9986             6                    Yes             No           No
# 9990             6                    Yes             No           No
# 9992             7                    Yes             No          Yes
# 9993             6                     No            Yes           No
# 9995             6                     No             No           No
#
#       subscription_member  repeat_purchase_count  loyalty_points
# 2                     Yes                     30            1020
# 7                      No                      0               0
# 13                     No                     46            1242
# 18                    Yes                      4              60
# 22                     No                      6             264
# ...                   ...                    ...             ...
# 9986                  Yes                     13             403
# 9990                  Yes                      9             216
# 9992                  Yes                     36            1512
# 9993                   No                      0               0
# 9995                  Yes                     47            2021
#
# [3209 rows x 38 columns]

# %% [markdown]
# 1. 3209 pedidos tienen un monto final superior a 500USD

# %%
np = df["customer_segment"].value_counts(1)
np
# Out:
# customer_segment
# Returning Customer    0.2977
# New Customer          0.2522
# Loyal Customer        0.2166
# VIP Customer          0.1213
# Inactive Customer     0.1122
# Name: proportion, dtype: float64

# %% [markdown]
# 2. El 12% de los pedidos realizados son por VIP Customer

# %%
df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.type()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
df.query("customer_age_group == '25-34' and customer_gender == 'Female'")
df.query("customer_segment == 25-34 and customer_gender == Female")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\scope.py:232, in Scope.resolve(self, key, is_local)
#     231 if self.has_resolvers:
# --> 232     return self.resolvers[key]
#     234 # if we're here that means that we have no locals and we also have
#     235 # no resolvers
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\collections\__init__.py:1028, in ChainMap.__getitem__(self, key)
#    1027         pass
# -> 1028 return self.__missing__(key)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\collections\__init__.py:1020, in ChainMap.__missing__(self, key)
#    1019 def __missing__(self, key):
# -> 1020     raise KeyError(key)
#
# KeyError: 'Female'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\scope.py:243, in Scope.resolve(self, key, is_local)
#     239 try:
#     240     # last ditch effort we look in temporaries
#     241     # these are created when parsing indexing expressions
#     242     # e.g., df[df > 0]
# --> 243     return self.temps[key]
#     244 except KeyError as err:
#
# KeyError: 'Female'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.query("customer_segment == 25-34 and customer_gender == Female")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:5195, in DataFrame.query(self, expr, parser, engine, local_dict, global_dict, resolvers, level, inplace)
#    5191         if not isinstance(expr, str):
#    5192             msg = f"expr must be a string to be evaluated, {type(expr)} given"
#    5193             raise ValueError(msg)
#    5194
# -> 5195         res = self.eval(
#    5196             expr,
#    5197             level=level + 1,
#    5198             parser=parser,
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:5375, in DataFrame.eval(self, expr, inplace, **kwargs)
#    5371         if "target" not in kwargs:
#    5372             kwargs["target"] = self
#    5373         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    5374
# -> 5375         return _eval(expr, inplace=inplace, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\eval.py:370, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     361 # get our (possibly passed-in) scope
#     362 env = ensure_scope(
#     363     level + 1,
#     364     global_dict=global_dict,
#    (...)    367     target=target,
#     368 )
# --> 370 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     372 if engine == "numexpr" and (
#     373     (
#     374         is_extension_array_dtype(parsed_expr.terms.return_type)
#    (...)    383     )
#     384 ):
#     385     warnings.warn(
#     386         "Engine has switched to 'python' because numexpr does not support "
#     387         "extension array dtypes. Please set your engine to python manually.",
#     388         RuntimeWarning,
#     389         stacklevel=find_stack_level(),
#     390     )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:819, in Expr.__init__(self, expr, engine, parser, env, level)
#     817 self.parser = parser
#     818 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 819 self.terms = self.parse()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:838, in Expr.parse(self)
#     834 def parse(self):
#     835     """
#     836     Parse an expression.
#     837     """
# --> 838     return self._visitor.visit(self.expr)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:426, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     424     raise SyntaxError("only a single expression is allowed")
#     425 expr = node.body[0]
# --> 426 return self.visit(expr, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:429, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     428 def visit_Expr(self, node, **kwargs):
# --> 429     return self.visit(node.value, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:756, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     753     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     755 operands = node.values
# --> 756 return reduce(visitor, operands)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:750, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     748 def visitor(x, y):
#     749     lhs = self._try_visit_binop(x)
# --> 750     rhs = self._try_visit_binop(y)
#     752     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#     753     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:745, in BaseExprVisitor._try_visit_binop(self, bop)
#     743 if isinstance(bop, (Op, Term)):
#     744     return bop
# --> 745 return self.visit(bop)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:729, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     727     op = self.translate_In(ops[0])
#     728     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 729     return self.visit(binop)
#     731 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     732 left = node.left
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:541, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     540 def visit_BinOp(self, node, **kwargs):
# --> 541     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     542     left, right = self._maybe_downcast_constants(left, right)
#     543     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:462, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     460     left = self.visit(node.left, side="left")
#     461 if right is None:
# --> 462     right = self.visit(node.right, side="right")
#     463 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     464 return op, op_class, left, right
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:420, in BaseExprVisitor.visit(self, node, **kwargs)
#     418 method = f"visit_{type(node).__name__}"
#     419 visitor = getattr(self, method)
# --> 420 return visitor(node, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\expr.py:551, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     550 def visit_Name(self, node, **kwargs) -> Term:
# --> 551     return self.term_type(node.id, self.env, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and isinstance(res.ndim, int) and res.ndim > 2:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\computation\scope.py:245, in Scope.resolve(self, key, is_local)
#     243     return self.temps[key]
#     244 except KeyError as err:
# --> 245     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'Female' is not defined

# %%
gf["customer_gender"].value_counts(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 gf["customer_gender"].value_counts(1)
#
# NameError: name 'gf' is not defined
