# %%
import pandas as pd

# %%
df = pd.read_csv("ecommerce_sales_customer_behavior.csv")
df
# Out:
#         order_id  year  month quarter is_weekend_order       platform  \
# 0     ORD0000001  2022      4      Q2              Yes     AliExpress
# 1     ORD0000002  2023      6      Q2              Yes       Flipkart
# 2     ORD0000003  2022      2      Q1              Yes         Amazon
# 3     ORD0000004  2022      7      Q3               No     AliExpress
# 4     ORD0000005  2024      4      Q2               No          Daraz
# ...          ...   ...    ...     ...              ...            ...
# 9995  ORD0009996  2022      3      Q1               No         Amazon
# 9996  ORD0009997  2021     11      Q4               No         Amazon
# 9997  ORD0009998  2021     10      Q4              Yes           eBay
# 9998  ORD0009999  2023      2      Q1              Yes           eBay
# 9999  ORD0010000  2023      6      Q2               No  Shopify Store
#
#          country customer_segment customer_age_group customer_gender  ...  \
# ...

# %% [markdown]
# En el df aparecen variables que representan fechas,informacion que identifica al cliente, como el pais, genero, edad, el tipo de cliente que es,datos sobre el tipo de compra que realizo, cuan recurrente es  y datos ordinales representados en si y no (1 y 0).

# %%
df[df["final_amount_usd"] > 500]
# Out:
#         order_id  year  month quarter is_weekend_order    platform    country  \
# 2     ORD0000003  2022      2      Q1              Yes      Amazon     Turkey
# 7     ORD0000008  2024     10      Q4              Yes        eBay      India
# 13    ORD0000014  2022      3      Q1              Yes  AliExpress        UAE
# 18    ORD0000019  2022      3      Q1               No        eBay        UAE
# 22    ORD0000023  2023      3      Q1              Yes      Amazon         UK
# ...          ...   ...    ...     ...              ...         ...        ...
# 9986  ORD0009987  2024      7      Q3              Yes        eBay    Germany
# 9990  ORD0009991  2024      2      Q1              Yes        eBay      India
# 9992  ORD0009993  2021      8      Q3              Yes    Flipkart        UAE
# 9993  ORD0009994  2024      1      Q1               No       Daraz      India
# 9995  ORD0009996  2022      3      Q1               No      Amazon  Australia
#
# ...

# %% [markdown]
# 1. 3209 pedidos tienen un monto final superior a 500USD

# %%
np = df["customer_segment"].value_counts(1)
np
# Out:
# customer_segment
# Returning Customer    0.2977
# New Customer          0.2522
# Loyal Customer        0.2166
# VIP Customer          0.1213
# Inactive Customer     0.1122
# Name: proportion, dtype: float64

# %% [markdown]
# 2. El 12% de los pedidos realizados son por VIP Customer

# %%
df.query("customer_age_group == '25-34' and customer_gender == 'Female'")
# Out:
#         order_id  year  month quarter is_weekend_order       platform  \
# 5     ORD0000006  2022      4      Q2               No         Amazon
# 8     ORD0000009  2023     10      Q4               No           eBay
# 10    ORD0000011  2024      1      Q1               No  Shopify Store
# 12    ORD0000013  2021     10      Q4              Yes           eBay
# 18    ORD0000019  2022      3      Q1               No           eBay
# ...          ...   ...    ...     ...              ...            ...
# 9937  ORD0009938  2024     12      Q4              Yes       Flipkart
# 9942  ORD0009943  2023     11      Q4              Yes           Etsy
# 9952  ORD0009953  2021      1      Q1               No          Daraz
# 9963  ORD0009964  2023      7      Q3              Yes           eBay
# 9985  ORD0009986  2023      2      Q1              Yes    WooCommerce
#
#            country    customer_segment customer_age_group customer_gender  \
# ...

# %% [markdown]
# 3. 1471 pedidos fueron hechos por mujeres entre 25-34 años.

# %%
cf = df.query("customer_satisfaction == 'Dissatisfied' or customer_satisfaction == 'Very Dissatisfied' and returned == 'Yes'")
cf["product_category"].value_counts()
# Out:
# product_category
# Electronics               133
# Fashion & Apparel         114
# Home & Kitchen            112
# Beauty & Personal Care     90
# Mobile & Tablets           63
# Sports & Fitness           60
# Food & Grocery             56
# Health & Wellness          45
# Books & Education          42
# Toys & Games               37
# Automotive                 26
# Jewelry & Accessories      21
# Name: count, dtype: int64

# %%
cf["product_category"].value_counts().sum()
# Out:
# np.int64(943)

# %% [markdown]
# 4. Fueron devueltos 943 pediodos con calificación "Dissatisfied" ó "Very Dissatisfied" siendo Electronics el tipo de producto que mas fue devuelto con 133

# %%
df.query("is_weekend_order == 'Yes' and discount_pct == 0")
# Out:
#         order_id  year  month quarter is_weekend_order     platform  \
# 9     ORD0000010  2023      1      Q1              Yes  WooCommerce
# 16    ORD0000017  2024      1      Q1              Yes         eBay
# 20    ORD0000021  2024      6      Q2              Yes     Flipkart
# 22    ORD0000023  2023      3      Q1              Yes       Amazon
# 28    ORD0000029  2023      1      Q1              Yes       Amazon
# ...          ...   ...    ...     ...              ...          ...
# 9963  ORD0009964  2023      7      Q3              Yes         eBay
# 9980  ORD0009981  2021      4      Q2              Yes   AliExpress
# 9985  ORD0009986  2023      2      Q1              Yes  WooCommerce
# 9988  ORD0009989  2023     11      Q4              Yes        Daraz
# 9990  ORD0009991  2024      2      Q1              Yes         eBay
#
#            country    customer_segment customer_age_group customer_gender  \
# 9           Canada        New Customer              18-24            Male
# ...

# %%
df.query("customer_segment == 'Inactive Customer' and discount_pct > 30")
# Out:
#         order_id  year  month quarter is_weekend_order       platform  \
# 299   ORD0000300  2021     11      Q4               No       Flipkart
# 470   ORD0000471  2021      3      Q1               No    WooCommerce
# 712   ORD0000713  2024     12      Q4              Yes         Amazon
# 795   ORD0000796  2024     10      Q4               No    WooCommerce
# 849   ORD0000850  2023      6      Q2               No          Daraz
# ...          ...   ...    ...     ...              ...            ...
# 9788  ORD0009789  2024      3      Q1               No           eBay
# 9805  ORD0009806  2023      3      Q1               No  Shopify Store
# 9898  ORD0009899  2024      1      Q1              Yes       Flipkart
# 9973  ORD0009974  2023      6      Q2              Yes          Jumia
# 9991  ORD0009992  2022      4      Q2               No       Flipkart
#
#          country   customer_segment customer_age_group customer_gender  ...  \
# ...
